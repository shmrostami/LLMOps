# %%
import whisper

# %%
# بارگذاری مدل (base برای سرعت، large برای دقت بیشتر)
model = whisper.load_model("base")  # یا "large-v3" برای بهترین دقت

# %%
# تبدیل صوت به متن (زبان را fa مشخص کنید)
result = model.transcribe("D:/Marefate_Nafs_J1.mp3", language="fa" , fp16=False)

print(result["text"])  # خروجی: متن فارسی استخراج‌شده
# Out:
#  بحظمرSho� رب العالم نše بحظمرSho� رötه جیألمه این AV s�س سکین اكن سوانيا Routeه مولوان امیر مقم Negro Пرونencie و سارتそしてдеي که ن миним Alexander ارسدین عال Ancient ایده سیده بیت رو اره همیده ازیزونه روز دار ارومی میدوری ورمی دست کن شاوندون دوره من با چون پاکتون ورومی ارشیتون اهنه ملقوده آلان ماشن خدا وان رو بر تو فیرد ارسی آوید تیوادت حاید این ماشنید شاکر گزاری و همچنی بزوطتین شاکر من سر این دوزه ازیز این از که الحمد رداه رب در آنمین با دستان آغمی با اوشتاقانه ده کمالر اریغتی محشور شدیه محسی چراد باید خدا وانزا شاکر فنی چراد باید خد دان شما روشی ازیش ارقیمت شما رو بیدان کدر این روز به اختزاری اخل اینسانیتون به اختزاری تابئی اخشیدون بجاییم که اخت شریفتون رو در آمورن مصقال افن اشتمای بوکسرونی لر ما ال اونس بجنسیه در آمورنی لر ما ال اونس بجنسیه اونس محقل این خوش این در سباخ و حرق این کنور آم دگر جمشوی این رومیگن این رومیگن شیری می این رومیگوین حلاوظ جنوویر سید سوزیدیم باخد در خلوظ خونی اشخش که خداویت بارک و تاولا تر نهون خانیت ایوش بخلبت این شینن میفر موید ایلاوه شکر که مرابه حنو ات ب
# ...

# %%
from hezar.models import Model

# %%
model = Model.load("hezarai/whisper-small-fa")

# %%
transcripts = model.predict("D:/Marefate_Nafs_J1-02.mp3")
print(transcripts)
# Out:
# [{'text': 'زلاح رحمان الرشیم، هو:'}]

# %%
transcripts
# Out:
# [{'text': 'الحملاله رب العالمین،الحملاله زده جعلانان،انرماعت مسکینه به قلایت مولانان،امیر المومنین،مولاد المعصومین،سلامالله علیهٔ عجمعین'}]
